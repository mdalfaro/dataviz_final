# %%
import pandas as pd
import numpy as np

# %%
all_qbs = pd.read_csv('qb.csv')

# %%
qbs = ['Tom Brady', 'Drew Brees', 'Philip Rivers', 'Eli Manning',
      'Ben Roethlisberger', 'Aaron Rodgers', 'Peyton Manning']

# %%
select_qbs = all_qbs[all_qbs['name'].isin(qbs)][['name', 'fpts', 'year']]

# %%
select_qbs.groupby(['name', 'year']).sum().to_csv('test.csv')

# %%
test = pd.read_csv('select_qbs.csv')

# %%
df = pd.DataFrame(0, index=np.arange(len(test['year'].unique())), columns=['year']+qbs)

# %%
df['year'] = test['year'].unique()

# %%
for row in df.iterrows():
    for qb in qbs:
        try: 
            fpts = test[test['name']==qb].groupby(['year'])['fpts'].sum().loc[row[1]['year']]
            df.at[row[0], qb] = fpts
        except:
            pass

# %%
df.sort_values(['year'], inplace=True)

# %%
df.to_csv('fpts_per_year.csv', index=False)

# %%
df.head()
# Out:
#     year  Tom Brady  Drew Brees  Philip Rivers  Eli Manning  \
# 18  2000          0           0              0            0
# 15  2001        218          16              0            0
# 16  2002        317         251              0            0
# 17  2003        285         158              0            0
# 14  2004        299         286              5           79
#
#     Ben Roethlisberger  Aaron Rodgers  Peyton Manning
# 18                   0              0             370
# 15                   0              0             350
# 16                   0              0             345
# 17                   0              0             332
# 14                 219              0             427

# %%
import matplotlib.pyplot as plt

# %%
# Out:
#      year                name   fpts
# 0    2005       Aaron Rodgers    4.0
# 1    2006       Aaron Rodgers    3.4
# 2    2007       Aaron Rodgers   17.9
# 3    2008       Aaron Rodgers  358.8
# 4    2009       Aaron Rodgers  402.5
# 5    2010       Aaron Rodgers  368.1
# 6    2011       Aaron Rodgers  456.3
# 7    2012       Aaron Rodgers  409.5
# 8    2013       Aaron Rodgers  207.0
# 9    2014       Aaron Rodgers  410.3
# 10   2015       Aaron Rodgers  356.0
# 11   2016       Aaron Rodgers  442.8
# 12   2017       Aaron Rodgers  160.6
# 13   2018       Aaron Rodgers  361.3
# 14   2004  Ben Roethlisberger  219.8
# 15   2005  Ben Roethlisberger  212.5
# 16   2006  Ben Roethlisberger  270.4
# 17   2007  Ben Roethlisberger  318.6
# 18   2008  Ben Roethlisberger  256.2
# 19   2009  Ben Roethlisberger  340.9
# 20   2010  Ben Roethlisberger  257.9
# 21   2011  Ben Roethlisberger  295.1
# 22   2012  Ben Roethlisberger  276.7
# 23   2013  Ben Roethlisberger  341.5
# 24   2014  Ben Roethlisberger  378.7
# 25   2015  Ben Roethlisberger  283.8
# 26   2016  Ben Roethlisberger  314.7
# 27   2017  Ben Roethlisberger  329.6
# 28   2018  Ben Roethlisberger  420.6
# 29   2001          Drew Brees   16.9
# ..    ...                 ...    ...
# 81   2008       Philip Rivers  345.0
# 82   2009       Philip Rivers  336.1
# 83   2010       Philip Rivers  361.2
# 84   2011       Philip Rivers  349.1
# 85   2012       Philip Rivers  288.7
# 86   2013       Philip Rivers  359.6
# 87   2014       Philip Rivers  349.1
# 88   2015       Philip Rivers  358.8
# 89   2016       Philip Rivers  355.4
# 90   2017       Philip Rivers  338.0
# 91   2018       Philip Rivers  344.5
# 92   2000           Tom Brady    0.3
# 93   2001           Tom Brady  218.7
# 94   2002           Tom Brady  317.6
# 95   2003           Tom Brady  285.7
# 96   2004           Tom Brady  299.7
# 97   2005           Tom Brady  324.8
# 98   2006           Tom Brady  283.3
# 99   2007           Tom Brady  462.6
# 100  2008           Tom Brady    3.8
# 101  2009           Tom Brady  342.6
# 102  2010           Tom Brady  348.3
# 103  2011           Tom Brady  447.3
# 104  2012           Tom Brady  405.0
# 105  2013           Tom Brady  319.2
# 106  2014           Tom Brady  343.7
# 107  2015           Tom Brady  406.1
# 108  2016           Tom Brady  296.2
# 109  2017           Tom Brady  360.1
# 110  2018           Tom Brady  349.6
#
# [111 rows x 3 columns]

# %%
labs = []
for x in range(0, 19):
    if len(str(x)) == 1: 
        x = '0' + str(x)
    x = "'" + str(x)
    labs.append(x)

# %%
plt.boxplot(df.drop('year', axis=1))
plt.xticks(list(range(1,20)), labs)
plt.title('Variation of QB Points')
plt.ylabel('Fantasy Points')
plt.xlabel('Year 20__')
# Out:
# Text(0.5,0,'Year 20__')

# %%
df.at[5, 'Tom Brady'] = 10

# %%
df.head()

# %%
df[(df['Time'] == 2000.0625)]['Tom Brady'] = 10
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for qb in qbs: 
    df[qb] = df[qb].cumsum()

# %%
df.to_csv('select_qbs.csv', index=False)

# %%
select_qbs
# Out:
#                      name  fpts  timestamp
# 12         Peyton Manning  17.4  2000.0625
# 42         Peyton Manning  32.4  2000.1250
# 123        Peyton Manning  38.4  2000.2500
# 181        Peyton Manning  19.5  2000.3125
# 214        Peyton Manning  21.4  2000.3750
# 259        Peyton Manning  18.1  2000.4375
# 291        Peyton Manning  25.4  2000.5000
# 332        Peyton Manning  26.4  2000.5625
# 371        Peyton Manning  25.3  2000.6250
# 425        Peyton Manning  14.7  2000.6875
# 457        Peyton Manning  26.7  2000.7500
# 505        Peyton Manning  21.1  2000.8125
# 532             Tom Brady   0.3  2000.8125
# 546        Peyton Manning  25.0  2000.8750
# 622        Peyton Manning   6.4  2000.9375
# 646        Peyton Manning  22.3  2001.0000
# 693        Peyton Manning  30.1  2001.0625
# 748        Peyton Manning  21.5  2001.0625
# 780        Peyton Manning  45.7  2001.1250
# 807             Tom Brady   3.2  2001.1250
# 828        Peyton Manning  21.2  2001.1875
# 845             Tom Brady   8.6  2001.1875
# 897             Tom Brady   5.2  2001.2500
# 901            Drew Brees   0.0  2001.2500
